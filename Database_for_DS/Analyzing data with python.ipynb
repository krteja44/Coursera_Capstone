# %% [markdown]
# <a href="https://cognitiveclass.ai"><img src = "https://ibm.box.com/shared/static/ugcqz6ohbvff804xp84y4kqnvvk3bq1g.png" width = 300, align = "center"></a>
#
# <h1 align=center><font size = 5>Lab: Analyzing a real world data-set with SQL and Python</font></h1>

# %% [markdown]
# # Introduction
#
# This notebook shows how to store a dataset into a database and analyze data using SQL and Python. In this lab you will:
# 1. Understand a dataset of selected socioeconomic indicators in Chicago
# 1. Learn how to store data in an Db2 database on IBM Cloud instance
# 1. Solve example problems to practice your SQL skills

# %% [markdown]
# ## Selected Socioeconomic Indicators in Chicago
#
# The city of Chicago released a dataset of socioeconomic data to the Chicago City Portal.
# This dataset contains a selection of six socioeconomic indicators of public health significance and a “hardship index,” for each Chicago community area, for the years 2008 – 2012.
#
# Scores on the hardship index can range from 1 to 100, with a higher index number representing a greater level of hardship.
#
# A detailed description of the dataset can be found on [the city of Chicago's website](
# https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2), but to summarize, the dataset has the following variables:
#
# * **Community Area Number** (`ca`): Used to uniquely identify each row of the dataset
#
# * **Community Area Name** (`community_area_name`): The name of the region in the city of Chicago
#
# * **Percent of Housing Crowded** (`percent_of_housing_crowded`): Percent of occupied housing units with more than one person per room
#
# * **Percent Households Below Poverty** (`percent_households_below_poverty`): Percent of households living below the federal poverty line
#
# * **Percent Aged 16+ Unemployed** (`percent_aged_16_unemployed`): Percent of persons over the age of 16 years that are unemployed
#
# * **Percent Aged 25+ without High School Diploma** (`percent_aged_25_without_high_school_diploma`): Percent of persons over the age of 25 years without a high school education
#
# * **Percent Aged Under** 18 or Over 64:Percent of population under 18 or over 64 years of age (`percent_aged_under_18_or_over_64`): (ie. dependents)
#
# * **Per Capita Income** (`per_capita_income_`): Community Area per capita income is estimated as the sum of tract-level aggragate incomes divided by the total population
#
# * **Hardship Index** (`hardship_index`): Score that incorporates each of the six selected socioeconomic indicators
#
# In this Lab, we'll take a look at the variables in the socioeconomic indicators dataset and do some basic analysis with Python.

# %% [markdown]
# ### Connect to the database
# Let us first load the SQL extension and establish a connection with the database

# %%
# !pip install ibm_db==2.0.8a
# Out:
# Collecting ibm_db==2.0.8a
#   Downloading https://files.pythonhosted.org/packages/02/76/2362a41e360596bb544ee0a85192fe26c3291d2fa595876e04f700a8f7a2/ibm_db-2.0.8a.tar.gz (689kB)
# Building wheels for collected packages: ibm-db
#   Running setup.py bdist_wheel for ibm-db: started
#   Running setup.py bdist_wheel for ibm-db: finished with status 'error'
#   Complete output from command C:\ProgramData\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\ravit\\AppData\\Local\\Temp\\pip-install-5h5hdsv1\\ibm-db\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" bdist_wheel -d C:\Users\ravit\AppData\Local\Temp\pip-wheel-ew_gg02k --python-tag cp37:
#   Detected 64-bit Python
#   C:\ProgramData\Anaconda3\lib\site-packages\setuptools\dist.py:470: UserWarning: Normalizing '2.0.8a' to '2.0.8a0'
#     normalized_version,
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build\lib.win-amd64-3.7
#   copying config.py -> build\lib.win-amd64-3.7
#   copying ibm_db_dbi.py -> build\lib.win-amd64-3.7
#   copying testfunctions.py -> build\lib.win-amd64-3.7
#   copying tests.py -> build\lib.win-amd64-3.7
#   creating build\lib.win-amd64-3.7\clidriver
#   copying clidriver\__init__.py -> build\lib.win-amd64-3.7\clidriver
#   creating build\lib.win-amd64-3.7\tests
#   copying tests\test_000_PrepareDb.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_001_ConnDb.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_002_ConnDbUncatalogedConn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_003_NumAffectedRows.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_004_ConnWrongUserPwd.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_005_ConnBadUserBadPwd.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_006_ConnPassingOpts.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_007_pConnPassingOpts.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_008_ColumnInfo.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_010_UpdateRowCount.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_011_DeleteRowCount.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_012_KeysetDrivenCursorSelect01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_013_KeysetDrivenCursorSelect02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_014_KeysetDrivenCursorNegativeRow.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_015_InsertDeleteRowCount_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_016_InsertDeleteRowCount_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_017_selectRowcountPrefetchSTMTOpt.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_018_selectRowcountPrefetchSetOpt.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_019_selectRowcountPrefetchPrepOpt.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_020_RollbackDelete.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_021_CommitDelete.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_022_RollbackInsert.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_023_ColumnPrivileges.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_024_ForeignKeys.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_025_PrimaryKeys.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_030_Result.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_031_ResultIndexPosition.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_032_ResultIndexName.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_033_ResultOutSequenceColumn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_034_FetchAssoc.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_035_FetchRow_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_036_FetchRow_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_037_FetchRowIndexPos.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_038_FetchRowIndexPosNested_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_039_FetchRowIndexPosNested_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_03a_ResultNonExistCol.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_040_FetchTuple.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_041_FetchTupleMany_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_042_FetchTupleMany_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_043_FetchTupleMany_03.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_044_FetchTupleMany_04.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_045_FetchTupleBinaryData_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_046_FetchTupleMany_05.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_047_FetchTupleMany_06.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_048_FetchTupleBinaryData_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_049_InsertNoneParam.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_050_AutocommitStatus.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_051_SetAutocommit_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_052_SetAutocommit_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_053_AttrThruConn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_054_CursorType.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_060_Tables_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_061_Tables_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_062_Tables_03.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_063_Tables_04.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_064_Tables_05.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_065_FilterTableName.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_066_TableObjects.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_070_Close.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_071_CloseSuccess.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_080_ConnWrongDbAlias.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_081_ConnWrongUser.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_082_ConnWrongPwd.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_090_ConnmsgWrongDbAlias.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_091_ConnmsgWrongUser.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_092_ConnmsgWrongPwd.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_100_SelectDeleteInsertFieldCount.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_101_InsertDeleteFieldCount.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_102_NumFieldsSelect_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_103_NumFieldsSelect_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_110_FieldNum.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_111_FieldNumAddCol.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_112_FieldNumDiffCaseColNames.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_113_DateTest.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_114_NumericTest_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_115_NumericTest_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_116_ConnActive.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_120_FieldName.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_121_FieldNameAddCol.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_122_FieldNameDiffCaseColNames.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_123_FieldNamePos_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_124_FieldNamePos_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_125_FieldNamePos_03.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_130_PrepExecuteSelectStmt.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_131_PrepareExecuteSelectStatementParams.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_132_ExecuteStatementArrayMultipleParams.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_133_ExecuteLongInputParams.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_140_BindParamSelectStmt.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_141_BindParamSelectStmtMultipleParams_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_142_BindParamSelectStmtMultipleParams_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_143_BindParamInsertStmtNoneParam.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_144_BindParamInsertStmtPARAM_FILE.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_145_BindRetrieveNoneEmptyString.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_146_CallSPINAndOUTParams.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_147_PrepareWithWrongType.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_148_CallSPDiffBindPattern_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_150_FetchAssocSelect_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_151_FetchAssocSelect_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_152_FetchAssocSelect_03.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_153_FetchAssocSelect_04.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_154_AllFetches.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_155_FetchAssocSelect_05.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_156_FetchAssocNestedSelects_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_157a_FetchAssocWithoutScrollableCursorErr.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_157b_FetchAssocScrollableCursor_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_157_FetchAssocScrollableCursor_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_158_FetchAssocNestedSelects_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_159a_FetchAssocSeveralRows_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_159_FetchAssocSeveralRows_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_160_FetchBoth.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_161_FetchBothNestedSelects_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_162_FetchBothNestedSelects_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_180_StmtErrMsg.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_190_ColumnsTable_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_191_ColumnsTable_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_195_InsertRetrieveXMLData_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_196_InsertRetrieveXMLData_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_197_StatisticsIndexes.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_200_MultipleRsltsetsUniformColDefs.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_201_MultipleRsltsetsDiffColDefs.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_210_FieldDisplaySize_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_211_FieldDisplaySize_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_212_FieldDisplaySize_03.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_213_FieldDisplaySize_04.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_220_PersistentConn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_221_100PersistentConns.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_230_FieldTypePos.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_231_FieldTypeName.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_232_FieldTypePosName.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_240_FieldWidthPosName_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_241_FieldWidthPosName_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_250_FreeResult_01.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_251_FreeResult_02.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_260_FetchTupleMany_07.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_261_FetchObjectAccess.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_264_InsertRetrieveBIGINTTypeColumn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_265_NoAffectedRows.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_300_ServerInfo.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_310_ClientInfo.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_311_InsertSelectDeleteNumLiterals.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_312_CacheBoundParameters.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_52949_TestSPIntVarcharXml.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_6528_ScopingProblemBindParam.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_6561_InsertNULLValues.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_6755_ExtraNULLChar_ResultCLOBCol.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_6792_FieldTypeRetStrDatetimeTimestamp.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_createdbNX.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_createDropDB.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_decfloat.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_decimal.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_execute_many.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_InsertRetrieveDateTimeTypeColumn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_recreateDB.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_spinout_timestamp.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_trusted_context_connect.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_trusted_context_pconnect.py -> build\lib.win-amd64-3.7\tests
#   copying tests\test_warn.py -> build\lib.win-amd64-3.7\tests
#   copying tests\__init__.py -> build\lib.win-amd64-3.7\tests
#   running egg_info
#   writing ibm_db.egg-info\PKG-INFO
#   writing dependency_links to ibm_db.egg-info\dependency_links.txt
#   writing top-level names to ibm_db.egg-info\top_level.txt
#   reading manifest file 'ibm_db.egg-info\SOURCES.txt'
#   reading manifest template 'MANIFEST.in'
#   warning: no files found matching 'README'
#   warning: no files found matching '*' under directory 'ibm_db_dlls'
#   writing manifest file 'ibm_db.egg-info\SOURCES.txt'
#   creating build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\DB2xml4c_cli64_5_8.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\DB2xml4c_cli64_5_8.dll.2.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBM.DB2.APP64.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBM.DB2.CLI64.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBM.DB2.CLIXML4C64.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBM.DB2.LDAP64.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBM.DB2.LDAPM64.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBM.DB2.SEC64.manifest -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBMIAMauth64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBMLDAPauthclient64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBMOSauthclient64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBMOSauthclientTwoPart64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBMkrb564.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\IBMkrb5TwoPart64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2app64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2cli.exe -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2cli64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2clixml4c64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2ldap64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2ldapm64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2level.exe -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2osse64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2trc.exe -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2trcapi64.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\db2trcd64.exe -> build\lib.win-amd64-3.7\clidriver\bin
#   copying clidriver\bin\ibmdadb264.dll -> build\lib.win-amd64-3.7\clidriver\bin
#   creating build\lib.win-amd64-3.7\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\amd64.VC12.CRT.manifest -> build\lib.win-amd64-3.7\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\msvcp120.dll -> build\lib.win-amd64-3.7\clidriver\bin\amd64.VC12.CRT
#   copying clidriver\bin\amd64.VC12.CRT\msvcr120.dll -> build\lib.win-amd64-3.7\clidriver\bin\amd64.VC12.CRT
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8cms_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8dbfl_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8iccs_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8kicc_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8km_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8msca_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8ssl_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8sys_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   copying clidriver\bin\icc64\gsk8valn_64.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64\c
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64\c\icc
#   copying clidriver\bin\icc64\c\icc\ReadMe.txt -> build\lib.win-amd64-3.7\clidriver\bin\icc64\c\icc
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\ICCSIG.txt -> build\lib.win-amd64-3.7\clidriver\bin\icc64\c\icc\icclib
#   copying clidriver\bin\icc64\c\icc\icclib\icclib084.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64\c\icc\icclib
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64\n
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64\n\icc
#   copying clidriver\bin\icc64\n\icc\ReadMe.txt -> build\lib.win-amd64-3.7\clidriver\bin\icc64\n\icc
#   creating build\lib.win-amd64-3.7\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\ICCSIG.txt -> build\lib.win-amd64-3.7\clidriver\bin\icc64\n\icc\icclib
#   copying clidriver\bin\icc64\n\icc\icclib\icclib085.dll -> build\lib.win-amd64-3.7\clidriver\bin\icc64\n\icc\icclib
#   creating build\lib.win-amd64-3.7\clidriver\bnd
#   copying clidriver\bnd\db2ajgrt.bnd -> build\lib.win-amd64-3.7\clidriver\bnd
#   copying clidriver\bnd\db2cli.bnd -> build\lib.win-amd64-3.7\clidriver\bnd
#   copying clidriver\bnd\db2cli.lst -> build\lib.win-amd64-3.7\clidriver\bnd
#   copying clidriver\bnd\db2clipk.bnd -> build\lib.win-amd64-3.7\clidriver\bnd
#   copying clidriver\bnd\db2clist.bnd -> build\lib.win-amd64-3.7\clidriver\bnd
#   copying clidriver\bnd\db2spcdb.bnd -> build\lib.win-amd64-3.7\clidriver\bnd
#   creating build\lib.win-amd64-3.7\clidriver\cfg
#   copying clidriver\cfg\DigiCertGlobalRootCA.arm -> build\lib.win-amd64-3.7\clidriver\cfg
#   copying clidriver\cfg\db2dsdriver.xsd -> build\lib.win-amd64-3.7\clidriver\cfg
#   creating build\lib.win-amd64-3.7\clidriver\conv
#   creating build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\04370923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\08500923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\08501252.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\08600923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\08630923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09230437.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09230850.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09230860.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09231043.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09231051.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09231114.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09231208.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09231252.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09231275.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09241252.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\09370950.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\10430923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\10510923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\11140923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\12080923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\12520850.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\12520923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\12750923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\1388ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00850.ucs -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM00923.ucs -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   copying clidriver\conv\alt\IBM01252.ucs -> build\lib.win-amd64-3.7\clidriver\conv\alt
#   creating build\lib.win-amd64-3.7\clidriver\conv\ms
#   copying clidriver\conv\ms\0930ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#   copying clidriver\conv\ms\0939ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#   copying clidriver\conv\ms\0943ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#   copying clidriver\conv\ms\0954ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#   copying clidriver\conv\ms\5039ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#   copying clidriver\conv\ms\ucs20943.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#   creating build\lib.win-amd64-3.7\clidriver\db2
#   copying clidriver\db2\db2diag.log -> build\lib.win-amd64-3.7\clidriver\db2
#   creating build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sql.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlca.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlcli.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlcli1.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlda.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlenv.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlext.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlstate.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlsystm.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqltypes.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlucode.h -> build\lib.win-amd64-3.7\clidriver\include
#   copying clidriver\include\sqlunx.h -> build\lib.win-amd64-3.7\clidriver\include
#   creating build\lib.win-amd64-3.7\clidriver\lib
#   copying clidriver\lib\db2app64.lib -> build\lib.win-amd64-3.7\clidriver\lib
#   copying clidriver\lib\db2cli64.lib -> build\lib.win-amd64-3.7\clidriver\lib
#   creating build\lib.win-amd64-3.7\clidriver\license
#   copying clidriver\license\odbc_REDIST.txt -> build\lib.win-amd64-3.7\clidriver\license
#   copying clidriver\license\odbc_notices.rtf -> build\lib.win-amd64-3.7\clidriver\license
#   creating build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#   creating build\lib.win-amd64-3.7\clidriver\msg
#   creating build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2adm.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2admh.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2caem.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cklog.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2cli.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clia1.lst -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clias.lst -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clih.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clit.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2clp2.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2fodc.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sql.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2sqlh.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying clidriver\msg\en_US\db2stt.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#   copying tests\pic1.jpg -> build\lib.win-amd64-3.7\tests
#   copying tests\spook.png -> build\lib.win-amd64-3.7\tests
#   Fixing build\lib.win-amd64-3.7\config.py build\lib.win-amd64-3.7\ibm_db_dbi.py build\lib.win-amd64-3.7\testfunctions.py build\lib.win-amd64-3.7\tests.py build\lib.win-amd64-3.7\clidriver\__init__.py build\lib.win-amd64-3.7\tests\test_000_PrepareDb.py build\lib.win-amd64-3.7\tests\test_001_ConnDb.py build\lib.win-amd64-3.7\tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.7\tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.7\tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.7\tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.7\tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_008_ColumnInfo.py build\lib.win-amd64-3.7\tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.7\tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.7\tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.7\tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.7\tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.7\tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.7\tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.7\tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.7\tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.7\tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.7\tests\test_020_RollbackDelete.py build\lib.win-amd64-3.7\tests\test_021_CommitDelete.py build\lib.win-amd64-3.7\tests\test_022_RollbackInsert.py build\lib.win-amd64-3.7\tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.7\tests\test_024_ForeignKeys.py build\lib.win-amd64-3.7\tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.7\tests\test_030_Result.py build\lib.win-amd64-3.7\tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.7\tests\test_032_ResultIndexName.py build\lib.win-amd64-3.7\tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.7\tests\test_034_FetchAssoc.py build\lib.win-amd64-3.7\tests\test_035_FetchRow_01.py build\lib.win-amd64-3.7\tests\test_036_FetchRow_02.py build\lib.win-amd64-3.7\tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.7\tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.7\tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.7\tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.7\tests\test_040_FetchTuple.py build\lib.win-amd64-3.7\tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.7\tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.7\tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.7\tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.7\tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.7\tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.7\tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.7\tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.7\tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.7\tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.7\tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.7\tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.7\tests\test_053_AttrThruConn.py build\lib.win-amd64-3.7\tests\test_054_CursorType.py build\lib.win-amd64-3.7\tests\test_060_Tables_01.py build\lib.win-amd64-3.7\tests\test_061_Tables_02.py build\lib.win-amd64-3.7\tests\test_062_Tables_03.py build\lib.win-amd64-3.7\tests\test_063_Tables_04.py build\lib.win-amd64-3.7\tests\test_064_Tables_05.py build\lib.win-amd64-3.7\tests\test_065_FilterTableName.py build\lib.win-amd64-3.7\tests\test_066_TableObjects.py build\lib.win-amd64-3.7\tests\test_070_Close.py build\lib.win-amd64-3.7\tests\test_071_CloseSuccess.py build\lib.win-amd64-3.7\tests\test_080_ConnWrongDbAlias.py build\lib.win-amd64-3.7\tests\test_081_ConnWrongUser.py build\lib.win-amd64-3.7\tests\test_082_ConnWrongPwd.py build\lib.win-amd64-3.7\tests\test_090_ConnmsgWrongDbAlias.py build\lib.win-amd64-3.7\tests\tes ...
#   Skipping optional fixer: buffer
#   Skipping optional fixer: idioms
#   Skipping optional fixer: set_literal
#   Skipping optional fixer: ws_comma
#   Fixing build\lib.win-amd64-3.7\config.py build\lib.win-amd64-3.7\ibm_db_dbi.py build\lib.win-amd64-3.7\testfunctions.py build\lib.win-amd64-3.7\tests.py build\lib.win-amd64-3.7\clidriver\__init__.py build\lib.win-amd64-3.7\tests\test_000_PrepareDb.py build\lib.win-amd64-3.7\tests\test_001_ConnDb.py build\lib.win-amd64-3.7\tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.7\tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.7\tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.7\tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.7\tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_008_ColumnInfo.py build\lib.win-amd64-3.7\tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.7\tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.7\tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.7\tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.7\tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.7\tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.7\tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.7\tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.7\tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.7\tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.7\tests\test_020_RollbackDelete.py build\lib.win-amd64-3.7\tests\test_021_CommitDelete.py build\lib.win-amd64-3.7\tests\test_022_RollbackInsert.py build\lib.win-amd64-3.7\tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.7\tests\test_024_ForeignKeys.py build\lib.win-amd64-3.7\tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.7\tests\test_030_Result.py build\lib.win-amd64-3.7\tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.7\tests\test_032_ResultIndexName.py build\lib.win-amd64-3.7\tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.7\tests\test_034_FetchAssoc.py build\lib.win-amd64-3.7\tests\test_035_FetchRow_01.py build\lib.win-amd64-3.7\tests\test_036_FetchRow_02.py build\lib.win-amd64-3.7\tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.7\tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.7\tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.7\tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.7\tests\test_040_FetchTuple.py build\lib.win-amd64-3.7\tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.7\tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.7\tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.7\tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.7\tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.7\tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.7\tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.7\tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.7\tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.7\tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.7\tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.7\tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.7\tests\test_053_AttrThruConn.py build\lib.win-amd64-3.7\tests\test_054_CursorType.py build\lib.win-amd64-3.7\tests\test_060_Tables_01.py build\lib.win-amd64-3.7\tests\test_061_Tables_02.py build\lib.win-amd64-3.7\tests\test_062_Tables_03.py build\lib.win-amd64-3.7\tests\test_063_Tables_04.py build\lib.win-amd64-3.7\tests\test_064_Tables_05.py build\lib.win-amd64-3.7\tests\test_065_FilterTableName.py build\lib.win-amd64-3.7\tests\test_066_TableObjects.py build\lib.win-amd64-3.7\tests\test_070_Close.py build\lib.win-amd64-3.7\tests\test_071_CloseSuccess.py build\lib.win-amd64-3.7\tests\test_080_ConnWrongDbAlias.py build\lib.win-amd64-3.7\tests\test_081_ConnWrongUser.py build\lib.win-amd64-3.7\tests\test_082_ConnWrongPwd.py build\lib.win-amd64-3.7\tests\test_090_ConnmsgWrongDbAlias.py build\lib.win-amd64-3.7\tests\tes ...
#   Skipping optional fixer: buffer
#   Skipping optional fixer: idioms
#   Skipping optional fixer: set_literal
#   Skipping optional fixer: ws_comma
#   running build_ext
#   building 'ibm_db' extension
#   error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": https://visualstudio.microsoft.com/downloads/
#
#   ----------------------------------------
#   Running setup.py clean for ibm-db
# Failed to build ibm-db
# Installing collected packages: ibm-db
#   Found existing installation: ibm-db 3.0.1
#     Uninstalling ibm-db-3.0.1:
#       Successfully uninstalled ibm-db-3.0.1
#   Running setup.py install for ibm-db: started
#     Running setup.py install for ibm-db: finished with status 'error'
#     Complete output from command C:\ProgramData\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\ravit\\AppData\\Local\\Temp\\pip-install-5h5hdsv1\\ibm-db\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\ravit\AppData\Local\Temp\pip-record-j35igi7u\install-record.txt --single-version-externally-managed --compile:
#     Detected 64-bit Python
#     C:\ProgramData\Anaconda3\lib\site-packages\setuptools\dist.py:470: UserWarning: Normalizing '2.0.8a' to '2.0.8a0'
#       normalized_version,
#     running install
#     running build
#     running build_py
#     creating build
#     creating build\lib.win-amd64-3.7
#     copying config.py -> build\lib.win-amd64-3.7
#     copying ibm_db_dbi.py -> build\lib.win-amd64-3.7
#     copying testfunctions.py -> build\lib.win-amd64-3.7
#     copying tests.py -> build\lib.win-amd64-3.7
#     creating build\lib.win-amd64-3.7\clidriver
#     copying clidriver\__init__.py -> build\lib.win-amd64-3.7\clidriver
#     creating build\lib.win-amd64-3.7\tests
#     copying tests\test_000_PrepareDb.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_001_ConnDb.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_002_ConnDbUncatalogedConn.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_003_NumAffectedRows.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_004_ConnWrongUserPwd.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_005_ConnBadUserBadPwd.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_006_ConnPassingOpts.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_007_pConnPassingOpts.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_008_ColumnInfo.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_010_UpdateRowCount.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_011_DeleteRowCount.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_012_KeysetDrivenCursorSelect01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_013_KeysetDrivenCursorSelect02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_014_KeysetDrivenCursorNegativeRow.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_015_InsertDeleteRowCount_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_016_InsertDeleteRowCount_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_017_selectRowcountPrefetchSTMTOpt.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_018_selectRowcountPrefetchSetOpt.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_019_selectRowcountPrefetchPrepOpt.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_020_RollbackDelete.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_021_CommitDelete.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_022_RollbackInsert.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_023_ColumnPrivileges.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_024_ForeignKeys.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_025_PrimaryKeys.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_030_Result.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_031_ResultIndexPosition.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_032_ResultIndexName.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_033_ResultOutSequenceColumn.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_034_FetchAssoc.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_035_FetchRow_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_036_FetchRow_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_037_FetchRowIndexPos.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_038_FetchRowIndexPosNested_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_039_FetchRowIndexPosNested_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_03a_ResultNonExistCol.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_040_FetchTuple.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_041_FetchTupleMany_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_042_FetchTupleMany_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_043_FetchTupleMany_03.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_044_FetchTupleMany_04.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_045_FetchTupleBinaryData_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_046_FetchTupleMany_05.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_047_FetchTupleMany_06.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_048_FetchTupleBinaryData_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_049_InsertNoneParam.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_050_AutocommitStatus.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_051_SetAutocommit_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_052_SetAutocommit_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_053_AttrThruConn.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_054_CursorType.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_060_Tables_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_061_Tables_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_062_Tables_03.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_063_Tables_04.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_064_Tables_05.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_065_FilterTableName.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_066_TableObjects.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_070_Close.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_071_CloseSuccess.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_080_ConnWrongDbAlias.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_081_ConnWrongUser.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_082_ConnWrongPwd.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_090_ConnmsgWrongDbAlias.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_091_ConnmsgWrongUser.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_092_ConnmsgWrongPwd.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_100_SelectDeleteInsertFieldCount.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_101_InsertDeleteFieldCount.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_102_NumFieldsSelect_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_103_NumFieldsSelect_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_110_FieldNum.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_111_FieldNumAddCol.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_112_FieldNumDiffCaseColNames.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_113_DateTest.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_114_NumericTest_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_115_NumericTest_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_116_ConnActive.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_120_FieldName.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_121_FieldNameAddCol.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_122_FieldNameDiffCaseColNames.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_123_FieldNamePos_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_124_FieldNamePos_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_125_FieldNamePos_03.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_130_PrepExecuteSelectStmt.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_131_PrepareExecuteSelectStatementParams.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_132_ExecuteStatementArrayMultipleParams.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_133_ExecuteLongInputParams.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_140_BindParamSelectStmt.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_141_BindParamSelectStmtMultipleParams_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_142_BindParamSelectStmtMultipleParams_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_143_BindParamInsertStmtNoneParam.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_144_BindParamInsertStmtPARAM_FILE.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_145_BindRetrieveNoneEmptyString.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_146_CallSPINAndOUTParams.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_147_PrepareWithWrongType.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_148_CallSPDiffBindPattern_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_150_FetchAssocSelect_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_151_FetchAssocSelect_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_152_FetchAssocSelect_03.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_153_FetchAssocSelect_04.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_154_AllFetches.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_155_FetchAssocSelect_05.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_156_FetchAssocNestedSelects_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_157a_FetchAssocWithoutScrollableCursorErr.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_157b_FetchAssocScrollableCursor_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_157_FetchAssocScrollableCursor_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_158_FetchAssocNestedSelects_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_159a_FetchAssocSeveralRows_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_159_FetchAssocSeveralRows_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_160_FetchBoth.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_161_FetchBothNestedSelects_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_162_FetchBothNestedSelects_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_180_StmtErrMsg.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_190_ColumnsTable_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_191_ColumnsTable_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_195_InsertRetrieveXMLData_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_196_InsertRetrieveXMLData_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_197_StatisticsIndexes.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_200_MultipleRsltsetsUniformColDefs.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_201_MultipleRsltsetsDiffColDefs.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_210_FieldDisplaySize_01.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_211_FieldDisplaySize_02.py -> build\lib.win-amd64-3.7\tests
#     copying tests\test_212_FieldDisplaySize_03.py -> build\lib.win-amd64-3.7\tests
# ...
#     copying clidriver\conv\alt\10430923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\10510923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\11140923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\12080923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\12520850.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\12520923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\12750923.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\1388ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\IBM00850.ucs -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\IBM00923.ucs -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     copying clidriver\conv\alt\IBM01252.ucs -> build\lib.win-amd64-3.7\clidriver\conv\alt
#     creating build\lib.win-amd64-3.7\clidriver\conv\ms
#     copying clidriver\conv\ms\0930ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#     copying clidriver\conv\ms\0939ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#     copying clidriver\conv\ms\0943ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#     copying clidriver\conv\ms\0954ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#     copying clidriver\conv\ms\5039ucs2.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#     copying clidriver\conv\ms\ucs20943.cnv -> build\lib.win-amd64-3.7\clidriver\conv\ms
#     creating build\lib.win-amd64-3.7\clidriver\db2
#     copying clidriver\db2\db2diag.log -> build\lib.win-amd64-3.7\clidriver\db2
#     creating build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sql.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlca.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlcli.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlcli1.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlda.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlenv.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlext.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlstate.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlsystm.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqltypes.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlucode.h -> build\lib.win-amd64-3.7\clidriver\include
#     copying clidriver\include\sqlunx.h -> build\lib.win-amd64-3.7\clidriver\include
#     creating build\lib.win-amd64-3.7\clidriver\lib
#     copying clidriver\lib\db2app64.lib -> build\lib.win-amd64-3.7\clidriver\lib
#     copying clidriver\lib\db2cli64.lib -> build\lib.win-amd64-3.7\clidriver\lib
#     creating build\lib.win-amd64-3.7\clidriver\license
#     copying clidriver\license\odbc_REDIST.txt -> build\lib.win-amd64-3.7\clidriver\license
#     copying clidriver\license\odbc_notices.rtf -> build\lib.win-amd64-3.7\clidriver\license
#     creating build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_br.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_cn.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_cz.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_de.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_el.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_en.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_es.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_fr.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_in.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_it.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_jp.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_kr.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_lt.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_pl.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_ru.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_sl.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_tr.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     copying clidriver\license\Windows\odbc_LI_tw.rtf -> build\lib.win-amd64-3.7\clidriver\license\Windows
#     creating build\lib.win-amd64-3.7\clidriver\msg
#     creating build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2adm.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2admh.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2caem.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2cklog.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2cli.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clia1.lst -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clias.lst -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clih.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clit.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clp.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2clp2.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2fodc.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2sql.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2sqlh.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying clidriver\msg\en_US\db2stt.mo -> build\lib.win-amd64-3.7\clidriver\msg\en_US
#     copying tests\pic1.jpg -> build\lib.win-amd64-3.7\tests
#     copying tests\spook.png -> build\lib.win-amd64-3.7\tests
#     Fixing build\lib.win-amd64-3.7\config.py build\lib.win-amd64-3.7\ibm_db_dbi.py build\lib.win-amd64-3.7\testfunctions.py build\lib.win-amd64-3.7\tests.py build\lib.win-amd64-3.7\clidriver\__init__.py build\lib.win-amd64-3.7\tests\test_000_PrepareDb.py build\lib.win-amd64-3.7\tests\test_001_ConnDb.py build\lib.win-amd64-3.7\tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.7\tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.7\tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.7\tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.7\tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_008_ColumnInfo.py build\lib.win-amd64-3.7\tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.7\tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.7\tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.7\tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.7\tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.7\tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.7\tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.7\tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.7\tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.7\tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.7\tests\test_020_RollbackDelete.py build\lib.win-amd64-3.7\tests\test_021_CommitDelete.py build\lib.win-amd64-3.7\tests\test_022_RollbackInsert.py build\lib.win-amd64-3.7\tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.7\tests\test_024_ForeignKeys.py build\lib.win-amd64-3.7\tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.7\tests\test_030_Result.py build\lib.win-amd64-3.7\tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.7\tests\test_032_ResultIndexName.py build\lib.win-amd64-3.7\tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.7\tests\test_034_FetchAssoc.py build\lib.win-amd64-3.7\tests\test_035_FetchRow_01.py build\lib.win-amd64-3.7\tests\test_036_FetchRow_02.py build\lib.win-amd64-3.7\tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.7\tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.7\tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.7\tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.7\tests\test_040_FetchTuple.py build\lib.win-amd64-3.7\tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.7\tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.7\tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.7\tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.7\tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.7\tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.7\tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.7\tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.7\tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.7\tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.7\tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.7\tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.7\tests\test_053_AttrThruConn.py build\lib.win-amd64-3.7\tests\test_054_CursorType.py build\lib.win-amd64-3.7\tests\test_060_Tables_01.py build\lib.win-amd64-3.7\tests\test_061_Tables_02.py build\lib.win-amd64-3.7\tests\test_062_Tables_03.py build\lib.win-amd64-3.7\tests\test_063_Tables_04.py build\lib.win-amd64-3.7\tests\test_064_Tables_05.py build\lib.win-amd64-3.7\tests\test_065_FilterTableName.py build\lib.win-amd64-3.7\tests\test_066_TableObjects.py build\lib.win-amd64-3.7\tests\test_070_Close.py build\lib.win-amd64-3.7\tests\test_071_CloseSuccess.py build\lib.win-amd64-3.7\tests\test_080_ConnWrongDbAlias.py build\lib.win-amd64-3.7\tests\test_081_ConnWrongUser.py build\lib.win-amd64-3.7\tests\test_082_ConnWrongPwd.py build\lib.win-amd64-3.7\tests\test_090_ConnmsgWrongDbAlias.py build\lib.win-amd64-3.7\tests\t ...
#     Skipping optional fixer: buffer
#     Skipping optional fixer: idioms
#     Skipping optional fixer: set_literal
#     Skipping optional fixer: ws_comma
#     Fixing build\lib.win-amd64-3.7\config.py build\lib.win-amd64-3.7\ibm_db_dbi.py build\lib.win-amd64-3.7\testfunctions.py build\lib.win-amd64-3.7\tests.py build\lib.win-amd64-3.7\clidriver\__init__.py build\lib.win-amd64-3.7\tests\test_000_PrepareDb.py build\lib.win-amd64-3.7\tests\test_001_ConnDb.py build\lib.win-amd64-3.7\tests\test_002_ConnDbUncatalogedConn.py build\lib.win-amd64-3.7\tests\test_003_NumAffectedRows.py build\lib.win-amd64-3.7\tests\test_004_ConnWrongUserPwd.py build\lib.win-amd64-3.7\tests\test_005_ConnBadUserBadPwd.py build\lib.win-amd64-3.7\tests\test_006_ConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_007_pConnPassingOpts.py build\lib.win-amd64-3.7\tests\test_008_ColumnInfo.py build\lib.win-amd64-3.7\tests\test_010_UpdateRowCount.py build\lib.win-amd64-3.7\tests\test_011_DeleteRowCount.py build\lib.win-amd64-3.7\tests\test_012_KeysetDrivenCursorSelect01.py build\lib.win-amd64-3.7\tests\test_013_KeysetDrivenCursorSelect02.py build\lib.win-amd64-3.7\tests\test_014_KeysetDrivenCursorNegativeRow.py build\lib.win-amd64-3.7\tests\test_015_InsertDeleteRowCount_01.py build\lib.win-amd64-3.7\tests\test_016_InsertDeleteRowCount_02.py build\lib.win-amd64-3.7\tests\test_017_selectRowcountPrefetchSTMTOpt.py build\lib.win-amd64-3.7\tests\test_018_selectRowcountPrefetchSetOpt.py build\lib.win-amd64-3.7\tests\test_019_selectRowcountPrefetchPrepOpt.py build\lib.win-amd64-3.7\tests\test_020_RollbackDelete.py build\lib.win-amd64-3.7\tests\test_021_CommitDelete.py build\lib.win-amd64-3.7\tests\test_022_RollbackInsert.py build\lib.win-amd64-3.7\tests\test_023_ColumnPrivileges.py build\lib.win-amd64-3.7\tests\test_024_ForeignKeys.py build\lib.win-amd64-3.7\tests\test_025_PrimaryKeys.py build\lib.win-amd64-3.7\tests\test_030_Result.py build\lib.win-amd64-3.7\tests\test_031_ResultIndexPosition.py build\lib.win-amd64-3.7\tests\test_032_ResultIndexName.py build\lib.win-amd64-3.7\tests\test_033_ResultOutSequenceColumn.py build\lib.win-amd64-3.7\tests\test_034_FetchAssoc.py build\lib.win-amd64-3.7\tests\test_035_FetchRow_01.py build\lib.win-amd64-3.7\tests\test_036_FetchRow_02.py build\lib.win-amd64-3.7\tests\test_037_FetchRowIndexPos.py build\lib.win-amd64-3.7\tests\test_038_FetchRowIndexPosNested_01.py build\lib.win-amd64-3.7\tests\test_039_FetchRowIndexPosNested_02.py build\lib.win-amd64-3.7\tests\test_03a_ResultNonExistCol.py build\lib.win-amd64-3.7\tests\test_040_FetchTuple.py build\lib.win-amd64-3.7\tests\test_041_FetchTupleMany_01.py build\lib.win-amd64-3.7\tests\test_042_FetchTupleMany_02.py build\lib.win-amd64-3.7\tests\test_043_FetchTupleMany_03.py build\lib.win-amd64-3.7\tests\test_044_FetchTupleMany_04.py build\lib.win-amd64-3.7\tests\test_045_FetchTupleBinaryData_01.py build\lib.win-amd64-3.7\tests\test_046_FetchTupleMany_05.py build\lib.win-amd64-3.7\tests\test_047_FetchTupleMany_06.py build\lib.win-amd64-3.7\tests\test_048_FetchTupleBinaryData_02.py build\lib.win-amd64-3.7\tests\test_049_InsertNoneParam.py build\lib.win-amd64-3.7\tests\test_050_AutocommitStatus.py build\lib.win-amd64-3.7\tests\test_051_SetAutocommit_01.py build\lib.win-amd64-3.7\tests\test_052_SetAutocommit_02.py build\lib.win-amd64-3.7\tests\test_053_AttrThruConn.py build\lib.win-amd64-3.7\tests\test_054_CursorType.py build\lib.win-amd64-3.7\tests\test_060_Tables_01.py build\lib.win-amd64-3.7\tests\test_061_Tables_02.py build\lib.win-amd64-3.7\tests\test_062_Tables_03.py build\lib.win-amd64-3.7\tests\test_063_Tables_04.py build\lib.win-amd64-3.7\tests\test_064_Tables_05.py build\lib.win-amd64-3.7\tests\test_065_FilterTableName.py build\lib.win-amd64-3.7\tests\test_066_TableObjects.py build\lib.win-amd64-3.7\tests\test_070_Close.py build\lib.win-amd64-3.7\tests\test_071_CloseSuccess.py build\lib.win-amd64-3.7\tests\test_080_ConnWrongDbAlias.py build\lib.win-amd64-3.7\tests\test_081_ConnWrongUser.py build\lib.win-amd64-3.7\tests\test_082_ConnWrongPwd.py build\lib.win-amd64-3.7\tests\test_090_ConnmsgWrongDbAlias.py build\lib.win-amd64-3.7\tests\t ...
#     Skipping optional fixer: buffer
#     Skipping optional fixer: idioms
#     Skipping optional fixer: set_literal
#     Skipping optional fixer: ws_comma
#     running build_ext
#     building 'ibm_db' extension
#     error: Microsoft Visual C++ 14.0 is required. Get it with "Microsoft Visual C++ Build Tools": https://visualstudio.microsoft.com/downloads/
#
#     ----------------------------------------
#   Rolling back uninstall of ibm-db
#   Failed building wheel for ibm-db
# Command "C:\ProgramData\Anaconda3\python.exe -u -c "import setuptools, tokenize;__file__='C:\\Users\\ravit\\AppData\\Local\\Temp\\pip-install-5h5hdsv1\\ibm-db\\setup.py';f=getattr(tokenize, 'open', open)(__file__);code=f.read().replace('\r\n', '\n');f.close();exec(compile(code, __file__, 'exec'))" install --record C:\Users\ravit\AppData\Local\Temp\pip-record-j35igi7u\install-record.txt --single-version-externally-managed --compile" failed with error code 1 in C:\Users\ravit\AppData\Local\Temp\pip-install-5h5hdsv1\ibm-db\

# %%
import ibm_db

# %%
#Replace the placeholder values with your actual Db2 hostname, username, and password:
dsn_hostname = "dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net" # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_uid = "fbm94113"        # e.g. "abc12345"
dsn_pwd = "mjzqzq60-2trfl2z"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "50000"                # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"

# %%
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

print(dsn)


try:
    conn = ibm_db.connect(dsn, "", "")
    print ("Connected to database: ", dsn_database, "as_user: ", dsn_uid, "on host: ", dsn_hostname)

except:
    print ("Unable to connect: ", ibm_db.conn_errormsg() )
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=BLUDB;HOSTNAME=dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net;PORT=50000;PROTOCOL=TCPIP;UID=fbm94113;PWD=mjzqzq60-2trfl2z;
# Connected to database:  BLUDB as_user:  fbm94113 on host:  dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net

# %%
ibm_db.close(conn)
# Out:
# True

# %%
username = "fbm94113"
password = "mjzqzq60-2trfl2z"
hostname = "dashdb-txn-sbox-yp-dal09-08.services.dal.bluemix.net"
port = 50000
db = "FBM94113"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-b3bed75c9d81> in <module>
# ----> 1 ibm_db_sa
#
# NameError: name 'ibm_db_sa' is not defined

# %%
# %sql ibm_db://username +":"+password +"@"+hostname+":"+port+"/"+dbname
# Out:
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])
# Can't load plugin: sqlalchemy.dialects:ibm_db
# Connection info needed in SQLAlchemy format, example:
#                postgresql://username:password@hostname/dbname
#                or an existing connection: dict_keys([])

# %% [markdown]
# ### Store the dataset in a Table
# ##### In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. To analyze the data using SQL, it first needs to be stored in the database.
#
# ##### We will first read the dataset source .CSV from the internet into pandas dataframe
#
# ##### Then we need to create a table in our Db2 database to store the dataset. The PERSIST command in SQL "magic" simplifies the process of table creation and writing the data from a `pandas` dataframe into the table

# %%
import pandas
chicago_socioeconomic_data = pandas.read_csv('https://data.cityofchicago.org/resource/jcxq-k9xf.csv')
# %sql PERSIST chicago_socioeconomic_data

# %% [markdown]
# ##### You can verify that the table creation was successful by making a basic query like:

# %%
# %sql SELECT * FROM chicago_socioeconomic_data limit 5;

# %% [markdown]
# ## Problems
#
# ### Problem 1
#
# ##### How many rows are in the dataset?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# %sql SELECT COUNT(*) FROM chicago_socioeconomic_data;
#
# Correct answer: 78
#
# -->

# %% [markdown]
# ### Problem 2
#
# ##### How many community areas in Chicago have a hardship index greater than 50.0?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# %sql SELECT COUNT(*) FROM chicago_socioeconomic_data WHERE hardship_index > 50.0;
# Correct answer: 38
# -->

# %% [markdown]
# ### Problem 3
#
# ##### What is the maximum value of hardship index in this dataset?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# %sql SELECT MAX(hardship_index) FROM chicago_socioeconomic_data;
#
# Correct answer: 98.0
# -->

# %% [markdown]
# ### Problem 4
#
# ##### Which community area which has the highest hardship index?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# ## We can use the result of the last query to as an input to this query:
# %sql SELECT community_area_name FROM chicago_socioeconomic_data where hardship_index=98.0
#
# ## or another option:
# %sql SELECT community_area_name FROM chicago_socioeconomic_data ORDER BY hardship_index DESC NULLS LAST FETCH FIRST ROW ONLY;
#
# ## or you can use a sub-query to determine the max hardship index:
# %sql select community_area_name from chicago_socioeconomic_data where hardship_index = ( select max(hardship_index) from chicago_socioeconomic_data )
#
# Correct answer: 'Riverdale'
# -->

# %% [markdown]
# ### Problem 5
#
# ##### Which Chicago community areas have per-capita incomes greater than $60,000?

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
#
# %sql SELECT community_area_name FROM chicago_socioeconomic_data WHERE per_capita_income_ > 60000;
#
# Correct answer:Lake View,Lincoln Park, Near North Side, Loop
# -->

# %% [markdown]
# ### Problem 6
#
# ##### Create a scatter plot using the variables `per_capita_income_` and `hardship_index`. Explain the correlation between the two variables.

# %% [markdown]
# Double-click __here__ for the solution.
#
# <!-- Hint:
# # if the import command gives ModuleNotFoundError: No module named 'seaborn'
# # then uncomment the following line i.e. delete the # to install the seaborn package
# # !pip install seaborn
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
#
# income_vs_hardship = %sql SELECT per_capita_income_, hardship_index FROM chicago_socioeconomic_data;
# plot = sns.jointplot(x='per_capita_income_',y='hardship_index', data=income_vs_hardship.DataFrame())
#
# Correct answer:You can see that as Per Capita Income rises as the Hardship Index decreases. We see that the points on the scatter plot are somewhat closer to a straight line in the negative direction, so we have a negative correlation between the two variables.
# -->

# %% [markdown]
# ### Conclusion
#
# ##### Now that you know how to do basic exploratory data analysis using SQL and python visualization tools, you can further explore this dataset to see how the variable `per_capita_income_` is related to `percent_households_below_poverty` and `percent_aged_16_unemployed`. Try to create interesting visualizations!

# %% [markdown]
# ## Summary
#
# ##### In this lab you learned how to store a real world data set from the internet in a database (Db2 on IBM Cloud), gain insights into data using SQL queries. You also visualized a portion of the data in the database to see what story it tells.

# %% [markdown]
# Copyright &copy; 2018 [cognitiveclass.ai](cognitiveclass.ai?utm_source=bducopyrightlink&utm_medium=dswb&utm_campaign=bdu). This notebook and its source code are released under the terms of the [MIT License](https://bigdatauniversity.com/mit-license/).
